# %%
products=pd.read_csv("product.csv")
products.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3ec258333642> in <module>
# ----> 1 products=pd.read_csv("product.csv")
#       2 products.head()
#
# NameError: name 'pd' is not defined
