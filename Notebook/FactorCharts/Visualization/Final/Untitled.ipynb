# %%
# !pip install flask_sqlalchemy
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/ronaldclarke/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
